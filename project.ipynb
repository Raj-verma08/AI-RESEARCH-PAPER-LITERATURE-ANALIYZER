# %%
import pandas as pd

# %%
path = "F:/major project/arxiv-metadata-oai-snapshot.json"

# %%
sample_df = pd.read_json(path, lines=True, nrows=200000)

# %%
print(sample_df.shape)
sample_df.head(5)
# Out:
# (200000, 14)
#          id           submitter  \
# 0  704.0001      Pavel Nadolsky
# 1  704.0002        Louis Theran
# 2  704.0003         Hongjun Pan
# 3  704.0004        David Callan
# 4  704.0005  Alberto Torchinsky
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                    Ileana Streinu and Louis Theran
# 2                                        Hongjun Pan
# 3                                       David Callan
# 4           Wael Abu-Shammala and Alberto Torchinsky
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                   comments  \
# 0  37 pages, 15 figures; published version
# 1    To appear in Graphs and Combinatorics
# 2                      23 pages, 3 figures
# 3                                 11 pages
# 4                                     None
#
#                                  journal-ref                         doi  \
# 0                   Phys.Rev.D76:013009,2007  10.1103/PhysRevD.76.013009
# 1                                       None                        None
# 2                                       None                        None
# 3                                       None                        None
# 4  Illinois J. Math. 52 (2008) no.2, 681-689                        None
#
#           report-no       categories  \
# 0  ANL-HEP-PR-07-12           hep-ph
# 1              None    math.CO cs.CG
# 2              None   physics.gen-ph
# 3              None          math.CO
# 4              None  math.CA math.FA
#
#                                              license  \
# 0                                               None
# 1  http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                             abstract  \
# 0    A fully differential calculation in perturba...
# 1    We describe a new algorithm, the $(k,\ell)$-...
# 2    The evolution of Earth-Moon system is descri...
# 3    We show that a determinant of Stirling cycle...
# 4    In this paper we show how to compute the $\L...
#
#                                             versions update_date  \
# 0  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2  [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
#
#                                       authors_parsed
# 0  [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 1           [[Streinu, Ileana, ], [Theran, Louis, ]]
# 2                                 [[Pan, Hongjun, ]]
# 3                                [[Callan, David, ]]
# 4  [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]

# %%
from collections import Counter

category_count = Counter()

for cats in sample_df['categories'].dropna():
    category_count.update(cats.split())

# %%
all_data = category_count.most_common()

newSample_df = pd.DataFrame(all_data, columns=['Category', 'Count'])

print(newSample_df)
# Out:
#            Category  Count
# 0          astro-ph  19875
# 1            hep-ph  18093
# 2            hep-th  17056
# 3          quant-ph  12801
# 4             gr-qc  10754
# ..              ...    ...
# 148  physics.app-ph      3
# 149        q-fin.EC      2
# 150         eess.SY      1
# 151         econ.GN      1
# 152         eess.AS      1
#
# [153 rows x 2 columns]

# %%
qbio_df = newSample_df[newSample_df['Category'].str.contains('q-bio', na=False)]
print(qbio_df)
# Out:
#      Category  Count
# 76   q-bio.PE    917
# 78   q-bio.QM    865
# 85   q-bio.BM    589
# 94   q-bio.NC    446
# 99   q-bio.MN    425
# 113  q-bio.GN    289
# 114  q-bio.SC    279
# 121  q-bio.CB    241
# 131  q-bio.OT    161
# 135  q-bio.TO    141

# %%
from collections import Counter

category_count = Counter()

chunks = pd.read_json(path, lines=True, chunksize=10000)

for chunk in chunks:
    for cats in chunk['categories'].dropna():
        category_count.update(cats.split())

# %%
print(category_count.most_common(30))
# Out:
# [('cs.LG', 254055), ('hep-ph', 193922), ('cs.CV', 182139), ('hep-th', 180114), ('quant-ph', 174620), ('cs.AI', 163756), ('gr-qc', 119639), ('cond-mat.mtrl-sci', 106501), ('astro-ph', 105380), ('cs.CL', 102776), ('cond-mat.mes-hall', 99682), ('math-ph', 88340), ('math.MP', 88340), ('cond-mat.str-el', 81495), ('cond-mat.stat-mech', 80153), ('math.CO', 76323), ('stat.ML', 75866), ('astro-ph.CO', 75653), ('astro-ph.GA', 75512), ('math.AP', 72105), ('astro-ph.SR', 68125), ('astro-ph.HE', 67301), ('math.PR', 64203), ('nucl-th', 61712), ('math.OC', 59368), ('hep-ex', 59244), ('math.AG', 58440), ('physics.optics', 54738), ('cs.IT', 53186), ('math.IT', 53186)]

# %%
# get ALL categories
all_data = category_count.most_common()

df = pd.DataFrame(all_data, columns=['Category', 'Count'])

print(df)
# Out:
#      Category   Count
# 0       cs.LG  254055
# 1      hep-ph  193922
# 2       cs.CV  182139
# 3      hep-th  180114
# 4    quant-ph  174620
# ..        ...     ...
# 171   atom-ph     123
# 172  acc-phys      49
# 173  plasm-ph      38
# 174    ao-sci      17
# 175  bayes-an      16
#
# [176 rows x 2 columns]

# %%
qbio_df = df[df['Category'].str.contains('q-bio', na=False)]
print(qbio_df)
# Out:
#      Category  Count
# 91   q-bio.QM  12756
# 92   q-bio.PE  12749
# 96   q-bio.NC  11700
# 121  q-bio.BM   6611
# 134  q-bio.MN   4091
# 136  q-bio.GN   3711
# 144  q-bio.TO   2582
# 146  q-bio.CB   2412
# 152  q-bio.SC   1790
# 156  q-bio.OT   1544
# 159     q-bio   1356

# %%
chunk_size = 100000
medical_data = []

for chunk in pd.read_json(path, lines=True, chunksize=chunk_size):
    filtered = chunk[chunk['categories'].str.contains('q-bio', na=False)]
    medical_data.append(filtered)

final_medical_df = pd.concat(medical_data)

# %%
final_medical_df.shape
# Out:
# (53862, 14)

# %%
final_medical_df.head(5)
# Out:
#            id          submitter  \
# 20   704.0021     Yuichi Togashi
# 33   704.0034   Vasily Ogryzko V
# 35   704.0036  Eduardo D. Sontag
# 157  704.0158        Huijie Yang
# 190  704.0191       Peter Virnau
#
#                                                authors  \
# 20   Vanessa Casagrande, Yuichi Togashi, Alexander ...
# 33                                      Vasily Ogryzko
# 35                   Liming Wang and Eduardo D. Sontag
# 157       Fangcui Zhao, Huijie Yang, and Binghong Wang
# 190  Peter Virnau (1), Leonid A. Mirny (1,2), Mehra...
#
#                                                  title  \
# 20   Molecular Synchronization Waves in Arrays of A...
# 33   Origin of adaptive mutants: a quantum measurem...
# 35   A remark on the number of steady states in a m...
# 157           Complexities of Human Promoter Sequences
# 190  Intricate Knots in Proteins: Function and Evol...
#
#                                               comments  \
# 20                                  5 pages, 4 figures
# 33                                             5 pages
# 35   Resubmit with new results on the upper bound o...
# 157  5 pages, 3 figures, To appear in Journal of Th...
# 190                        6 pages, 2 figures, 1 table
#
#                                            journal-ref  \
# 20                  Phys. Rev. Lett. 99, 048301 (2007)
# 33                                                None
# 35                                                None
# 157  Journal of Theoretical Biology 247 (2007) 645?...
# 190  P. Virnau, L. A. Mirny, M. Kardar, PLoS Comp B...
#
#                                doi report-no  \
# 20   10.1103/PhysRevLett.99.048301      None
# 33                            None      None
# 35                            None      None
# 157     10.1016/j.jtbi.2007.03.035      None
# 190                           None      None
#
#                                   categories license  \
# 20          nlin.PS physics.chem-ph q-bio.MN    None
# 33                q-bio.PE q-bio.CB quant-ph    None
# 35                         q-bio.QM q-bio.MN    None
# 157                                 q-bio.OT    None
# 190  physics.bio-ph physics.data-an q-bio.BM    None
#
#                                               abstract  \
# 20     Spatiotemporal pattern formation in a produc...
# 33     This is a supplement to the paper arXiv:q-bi...
# 35     The multisite phosphorylation-dephosphorylat...
# 157    By means of the diffusion entropy approach, ...
# 190    A number of recently discovered protein stru...
#
#                                               versions update_date  \
# 20   [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-07-24
# 33   [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 35   [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2011-11-09
# 157  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2011-11-09
# 190  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2007-05-23
#
#                                         authors_parsed
# 20   [[Casagrande, Vanessa, ], [Togashi, Yuichi, ],...
# 33                               [[Ogryzko, Vasily, ]]
# 35          [[Wang, Liming, ], [Sontag, Eduardo D., ]]
# 157  [[Zhao, Fangcui, ], [Yang, Huijie, ], [Wang, B...
# 190  [[Virnau, Peter, ], [Mirny, Leonid A., ], [Kar...

# %%
columns_needed = [
    "id",
    "title",
    "abstract",
    "authors",
    "authors_parsed",
    "categories",
    "update_date",
    "journal-ref",
    "doi"
]

df = final_medical_df[columns_needed]

# %%
medical_df = df[
    df['update_date'] >= '2015-01-01'
]

# %%
medical_df.shape
# Out:
# (40649, 9)

# %%
medical_df['year'] = pd.to_datetime(medical_df['update_date']).dt.year
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_36444\608609611.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   medical_df['year'] = pd.to_datetime(medical_df['update_date']).dt.year

# %%
medical_df.head(5)
# Out:
#             id                                              title  \
# 1389   704.139      Velocity oscillations in actin-based motility
# 2199    704.22  Boolean network model predicts cell cycle sequ...
# 2546  704.2547  Inferring DNA sequences from mechanical unzipp...
# 3004  704.3005                          A balanced memory network
# 3225  704.3226     Delay estimation in a two-node acyclic network
#
#                                                abstract  \
# 1389    We present a simple and generic theoretical ...
# 2199    A Boolean network model of the cell-cycle re...
# 2546    The complementary strands of DNA molecules c...
# 3004    A fundamental problem in neuroscience is und...
# 3225    Linear measures such as cross-correlation ha...
#
#                                                 authors  \
# 1389            Azam Gholami, Martin Falcke, Erwin Frey
# 2199                Maria I. Davidich, Stefan Bornholdt
# 2546  Valentina Baldazzi (LPS), Serena Bradde (LPS),...
# 3004                      Yasser Roudi, Peter E. Latham
# 3225                            Radhakrishnan Nagarajan
#
#                                          authors_parsed  \
# 1389  [[Gholami, Azam, ], [Falcke, Martin, ], [Frey,...
# 2199    [[Davidich, Maria I., ], [Bornholdt, Stefan, ]]
# 2546  [[Baldazzi, Valentina, , LPS], [Bradde, Serena...
# 3004          [[Roudi, Yasser, ], [Latham, Peter E., ]]
# 3225                     [[Nagarajan, Radhakrishnan, ]]
#
#                        categories update_date  \
# 1389                     q-bio.CB  2015-05-13
# 2199                     q-bio.MN  2015-05-13
# 2546  q-bio.BM cond-mat.stat-mech  2015-05-13
# 3004     q-bio.NC cond-mat.dis-nn  2015-05-13
# 3225            q-bio.QM q-bio.MN  2015-05-13
#
#                                             journal-ref  \
# 1389                                               None
# 2199                                               None
# 2546                      Phys. Rev. E 75 (2007) 011904
# 3004                                               None
# 3225  Physica A: Volume 376, 15 March 2007, Pages 72...
#
#                                 doi  year
# 1389  10.1088/1367-2630/10/3/033022  2015
# 2199   10.1371/journal.pone.0001672  2015
# 2546     10.1103/PhysRevE.75.011904  2015
# 3004   10.1371/journal.pcbi.0030141  2015
# 3225    10.1016/j.physa.2006.10.067  2015

# %%
medical_df.shape
# Out:
# (40649, 10)

# %%
medical_df['year'].value_counts().sort_index()
# Out:
# year
# 2015    3531
# 2016    2701
# 2017    2469
# 2018    2612
# 2019    2900
# 2020    3943
# 2021    3580
# 2022    3334
# 2023    3852
# 2024    4475
# 2025    6227
# 2026    1025
# Name: count, dtype: int64
